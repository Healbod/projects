# %% [markdown]
# ***Описание признаков известные до определенной минуты***
#
# общая информация:
# * __('info', 'date', 'year')__
# * __('info', 'date', 'date')__
# * __('info', 'date', 'tour')__
# * __('info', 'stadium', 'judge')__
# * __('info', 'stadium', 'place')__
# * __('info', 'stadium', 'audience')__
# * __('info', 'stadium', 'full_audience')__
# * __('info', 'stadium', 'audience_ratio')__
#
# другие признаки
# * __('info', 'other', 'link')__
# * ('info', 'other', 'weather')
#
# информация о матче:
# * ('match', 'first_goal', 'team')
# * ('match', 'first_goal', 'time')
# * ('match', 'first_goal', 'name_player')
# * ('match', 'first_goal', 'name_assistant')
# * ('match', 'first_replacement', 'team')
# * ('match', 'first_replacement', 'time')
# * ('match', 'first_replacement', 'name_player_gone')
# * ('match', 'first_replacement', 'name_player_came')
# * ('match', 'first_yellow_card', 'team')
# * ('match', 'first_yellow_card', 'time')
# * ('match', 'first_yellow_card', 'name_player')
# * ('match', 'first_red_card', 'team')
# * ('match', 'first_red_card', 'time')
# * ('match', 'first_red_card', 'name_player')
#
# наборы признаков для каждой команды (guest and home):
# * __('guest', 'team', 'name')__
# * __('guest', 'team', 'trainer')__
# * ('guest', 'team', 'count_goal')
# * ('guest', 'team', 'count_yellow_card')
# * ('guest', 'team', 'count_red_card')
# * ('guest', 'team', 'replacement')
# * ('guest', 'team', 'games')
# * ('guest', 'team', 'win')
# * ('guest', 'team', 'draw')
# * ('guest', 'team', 'loss')
# * ('guest', 'team', 'goals_scored')
# * ('guest', 'team', 'goals_conceded')
# * ('guest', 'team', 'goals_difference')
# * ('guest', 'team', 'scores')
#
# наборы признаков для каждого игрока команды (guest and home):
# * ('guest', 'players', '1_name')...('guest', 'players', 'n_name') - none(0), reserve(1), play(2), assistance(3), goal(4*n_goal)
# * ('guest', 'players', '1_goal')...('guest', 'players', 'n_goal')
# * ('guest', 'players', '1_goal_time')...('guest', 'players', 'n_goal_time')
# * ('guest', 'players', '1_yellow_card')...('guest', 'players', 'n_yellow_card')
# * ('guest', 'players', '1_red_card')...('guest', 'players', 'n_red_card')
#
# predict:
# * ('total', 'home','goal_count')
# * ('total', 'guest','goal_count')
